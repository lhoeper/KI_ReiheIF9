# %% [markdown]
# # Erster Blick auf Python
# Bevor wir uns Datenbeispiele genauer anschauen, lernst du in diesem Notebook die Programmiersprache Python kennen.

# %%
# Hier werden Bibliotheken importiert
import pandas

# %% [markdown]
# ## Variablen in Python
# Daten können wir in Variablen und Tabellen speichern. Die **Variablen** kennst du schon aus Snap.

# %%
# Ich bin ein Kommentar
# In der nächsten Zeile gibt es eine Variable mit dem Namen x, die den Wert 5 bekommt
x = 5

# In der nächsten Zeile gibt es eine Variable mit dem Namen y, die den Wert 10 bekommt
y = 10

# Mit Variablen können wir rechnen
x+y

# %% [markdown]
# <font color='blue'>**Aufgabe:**</font> Wenn eine Zelle ausgeführt wird, wird darunter eine Ausgabe erzeugt. Beschreibe in der nächsten Zelle, was die Zahl bedeutet, die ausgegeben wurde, und zu welcher Zeile im Code sie gehört.

# %% [markdown]
# -> Notiere hier deine Lösung...

# %% [markdown]
# <font color='blue'>**Aufgabe:**</font> Erstelle in der nächsten Zeile zwei Variablen mit den Werten 6 und 5. Gib danach das Produkt (Multiplikation mit einem * geschrieben) aus.

# %%
# Hier kommt dein Code hin

# %% [markdown]
# ## Tabellen
# Nun schauen wir uns **Tabellen** an. In einer Tabelle können viele Daten gespeichert werden. Tabellen werden in Python als *Dataframes* bezeichnet. In der nächsten Zelle wird eine Beispieltabelle erstellt. Dafür nutzen wir ein Paket mit dem Namen *pandas*.

# %%
ersteTabelle = pandas.DataFrame([[1,2,3,4],[5,6,7,8]], columns=["Spalte 1", "Spalte 2", "Spalte 3", "Spalte 4"])
ersteTabelle

# %% [markdown]
# Um auf Werte der Tabelle zuzugreifen, gibt es verschiedene Varianten. Am häufigsten brauchen wir zunächst die Auswahl einer ganzen Spalte. Dazu schreiben wir hinter den Namen der Tabelle den Namen der Spalte in eckigen Klammern:
#
# ```ersteTabelle['Namen der Spalte']```

# %%
# Beispiel für die Spalte 1
ersteTabelle['Spalte 1']

# %% [markdown]
# <font color='blue'>**Aufgabe:**</font> Versuche die Ausgabe der vorherigen Zelle zu verstehen. Erzeuge in der nächsten Zelle einen Code, mit dem der Inhalt der dritten Spalte ausgegeben wird.

# %%
# Hier kommt dein Code hin

# %% [markdown]
# Mit Tabellen können wir arbeiten. Zur Verfügung stehen uns folgende Funktionen:
# - ```min()```
# - ```max()```
# - ```mean()```
# - ```median()```
# - ```sum()```
# - ```count()```
#
# Aufgerufen werden die Methoden wie folgt, um sie auf die Werte in einer Spalte anzuwenden:
#
# ```ersteTabelle["Spaltennamen"].min()```

# %% [markdown]
# <font color='blue'>**Aufgabe:**</font> Versuche für die fünf genannten Funktionen herauszufinden, was sie machen. Erstelle in der nächsten Zelle Code, um die geforderten Informationen für die zweite Spalte herauszufinden. Mit dem ```print()```-Befehl können wir eine saubere Ausgabe erzeugen.

# %%
# Beispiel: Es soll die Anzahl der Elemente in der Spalte 2 ausgegeben werden
print(ersteTabelle["Spalte 2"].count())

# %%
# Es soll die Summe der Elemente in der Spalte 2 ausgegeben werden

# %%
# Es soll das Mininum der Elemente in der Spalte 2 ausgegeben werden

# %%
# Es soll das Maximum der Elemente in der Spalte 2 ausgegeben werden
